# %% [markdown]
# <a href="https://colab.research.google.com/github/shreekrishna-sulu/shree/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 2
b = 5
print(a*b)
# Out:
# 10
